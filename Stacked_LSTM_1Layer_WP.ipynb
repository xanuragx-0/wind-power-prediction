# %% [markdown]
# <a href="https://colab.research.google.com/github/xanuragx-0/wind-power-prediction/blob/main/Stacked_LSTM_1Layer_WP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import  Sequential,layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

from pandas.plotting import register_matplotlib_converters
import seaborn as sns

from datetime import datetime
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %%
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
df.head()
# Out:
#                      DewPointC  cloudcover  ...  Direction    Energy
# date_time                                   ...
# 2014-01-01 00:00:00         12          87  ...      206.0   9.87333
# 2014-01-01 01:00:00         12          84  ...      200.0  10.24902
# 2014-01-01 02:00:00         12          81  ...      205.0  10.66536
# 2014-01-01 03:00:00         12          79  ...      195.0  12.29827
# 2014-01-01 04:00:00         12          73  ...      192.0  12.55498
#
# [5 rows x 8 columns]

# %% [markdown]
# # **Without Data preprocessing**

# %% [markdown]
# ### **Single layer 32 neurons**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(123)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 32, input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))

  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(GRU)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False, callbacks = [early_stop])
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 32)                3456
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 3,489
# Trainable params: 3,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 6s 8ms/step - loss: 0.0366 - val_loss: 0.0238
# Epoch 2/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0153 - val_loss: 0.0229
# Epoch 3/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0138 - val_loss: 0.0227
# Epoch 4/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0131 - val_loss: 0.0226
# Epoch 5/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0127 - val_loss: 0.0225
# Epoch 6/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0124 - val_loss: 0.0227
# Epoch 7/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0121 - val_loss: 0.0226
# Epoch 8/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0121 - val_loss: 0.0225
# Epoch 9/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0120 - val_loss: 0.0224
# Epoch 10/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0120 - val_loss: 0.0226
# Epoch 11/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0119 - val_loss: 0.0225
# Epoch 12/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0116 - val_loss: 0.0228
# Epoch 13/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0115 - val_loss: 0.0225
# Epoch 14/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0115 - val_loss: 0.0227
# Epoch 15/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0111 - val_loss: 0.0226
# Epoch 16/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0110 - val_loss: 0.0227
# Epoch 17/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0106 - val_loss: 0.0228
# Epoch 18/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0104 - val_loss: 0.0230
# Epoch 19/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0102 - val_loss: 0.0228
# Epoch 20/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0101 - val_loss: 0.0230
# Epoch 21/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0100 - val_loss: 0.0229
# Epoch 22/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0099 - val_loss: 0.0231
# Epoch 23/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0100 - val_loss: 0.0229
# Epoch 24/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0097 - val_loss: 0.0228
# Epoch 25/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0096 - val_loss: 0.0229
# Epoch 26/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0095 - val_loss: 0.0229
# Epoch 27/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0095 - val_loss: 0.0229
# Epoch 28/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0094 - val_loss: 0.0232
# Epoch 29/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0095 - val_loss: 0.0229
# Epoch 30/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0094 - val_loss: 0.0230
# Epoch 31/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0093 - val_loss: 0.0231
# Epoch 32/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0093 - val_loss: 0.0228
# Epoch 33/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0091 - val_loss: 0.0233
# Epoch 34/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0092 - val_loss: 0.0229
# Stacked LSTM:
# Mean Absolute Error: 1.18
# Root Mean Square Error: 1.87

# %% [markdown]
# ### **Single layer 16 neurons**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(123)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 16, input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))

  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(GRU)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False, callbacks = [early_stop])
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 16)                960
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 977
# Trainable params: 977
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 5s 7ms/step - loss: 0.0327 - val_loss: 0.0239
# Epoch 2/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0150 - val_loss: 0.0222
# Epoch 3/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0138 - val_loss: 0.0221
# Epoch 4/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0133 - val_loss: 0.0222
# Epoch 5/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0129 - val_loss: 0.0226
# Epoch 6/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0128 - val_loss: 0.0226
# Epoch 7/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0123 - val_loss: 0.0222
# Epoch 8/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0123 - val_loss: 0.0223
# Epoch 9/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0121 - val_loss: 0.0223
# Epoch 10/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0120 - val_loss: 0.0227
# Epoch 11/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0119 - val_loss: 0.0226
# Epoch 12/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0118 - val_loss: 0.0224
# Epoch 13/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0115 - val_loss: 0.0226
# Epoch 14/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0112 - val_loss: 0.0227
# Epoch 15/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0112 - val_loss: 0.0231
# Epoch 16/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0109 - val_loss: 0.0229
# Epoch 17/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0109 - val_loss: 0.0231
# Epoch 18/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0231
# Epoch 19/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0105 - val_loss: 0.0232
# Epoch 20/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0103 - val_loss: 0.0233
# Epoch 21/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0103 - val_loss: 0.0233
# Epoch 22/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0102 - val_loss: 0.0234
# Epoch 23/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0102 - val_loss: 0.0232
# Epoch 24/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0101 - val_loss: 0.0233
# Epoch 25/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0100 - val_loss: 0.0231
# Epoch 26/100
# 454/454 [==============================] - 3s 7ms/step - loss: 0.0100 - val_loss: 0.0233
# Epoch 27/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0100 - val_loss: 0.0231
# Epoch 28/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0099 - val_loss: 0.0232
# Stacked LSTM:
# Mean Absolute Error: 1.21
# Root Mean Square Error: 1.90

# %% [markdown]
# ### **Single layer 8 neurons**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(123)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 8, input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))

  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(GRU)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False, callbacks = [early_stop])
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 8)                 288
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 297
# Trainable params: 297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 5s 7ms/step - loss: 0.0312 - val_loss: 0.0267
# Epoch 2/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0162 - val_loss: 0.0247
# Epoch 3/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0151 - val_loss: 0.0240
# Epoch 4/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0145 - val_loss: 0.0234
# Epoch 5/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0139 - val_loss: 0.0237
# Epoch 6/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0138 - val_loss: 0.0240
# Epoch 7/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0133 - val_loss: 0.0237
# Epoch 8/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0133 - val_loss: 0.0240
# Epoch 9/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0132 - val_loss: 0.0237
# Epoch 10/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0130 - val_loss: 0.0240
# Epoch 11/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0130 - val_loss: 0.0236
# Epoch 12/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0129 - val_loss: 0.0238
# Epoch 13/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0127 - val_loss: 0.0240
# Epoch 14/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0125 - val_loss: 0.0240
# Epoch 15/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0126 - val_loss: 0.0237
# Epoch 16/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0124 - val_loss: 0.0238
# Epoch 17/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0121 - val_loss: 0.0239
# Epoch 18/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0121 - val_loss: 0.0239
# Epoch 19/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0118 - val_loss: 0.0237
# Epoch 20/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0116 - val_loss: 0.0240
# Epoch 21/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0116 - val_loss: 0.0238
# Epoch 22/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0113 - val_loss: 0.0241
# Epoch 23/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0113 - val_loss: 0.0239
# Epoch 24/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0112 - val_loss: 0.0240
# Epoch 25/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0111 - val_loss: 0.0242
# Epoch 26/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0242
# Epoch 27/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0109 - val_loss: 0.0241
# Epoch 28/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0240
# Epoch 29/100
# 454/454 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0239
# Stacked LSTM:
# Mean Absolute Error: 1.24
# Root Mean Square Error: 1.92

# %% [markdown]
# # **With Data Preprocessing**

# %% [markdown]
# ## **Single layer 32 neurons**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(12322)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)

df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
df.isnull().sum(axis = 0)
# Out:
# Speed (m/s)    0
# Direction      0
# Energy         0
# dtype: int64

# %%
#df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
#df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 32, input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))

  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(GRU)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False, callbacks = [early_stop])
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 32)                3456
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 3,489
# Trainable params: 3,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 5s 8ms/step - loss: 0.0371 - val_loss: 0.0253
# Epoch 2/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0152 - val_loss: 0.0248
# Epoch 3/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0138 - val_loss: 0.0245
# Epoch 4/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0130 - val_loss: 0.0246
# Epoch 5/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0127 - val_loss: 0.0242
# Epoch 6/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0125 - val_loss: 0.0237
# Epoch 7/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0122 - val_loss: 0.0238
# Epoch 8/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0122 - val_loss: 0.0235
# Epoch 9/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0121 - val_loss: 0.0239
# Epoch 10/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0119 - val_loss: 0.0240
# Epoch 11/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0119 - val_loss: 0.0236
# Epoch 12/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0117 - val_loss: 0.0237
# Epoch 13/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0116 - val_loss: 0.0237
# Epoch 14/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0116 - val_loss: 0.0235
# Epoch 15/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0116 - val_loss: 0.0235
# Epoch 16/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0111 - val_loss: 0.0235
# Epoch 17/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0108 - val_loss: 0.0237
# Epoch 18/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0107 - val_loss: 0.0236
# Epoch 19/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0103 - val_loss: 0.0236
# Epoch 20/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0101 - val_loss: 0.0238
# Epoch 21/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0100 - val_loss: 0.0236
# Epoch 22/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0100 - val_loss: 0.0235
# Epoch 23/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0098 - val_loss: 0.0235
# Epoch 24/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0097 - val_loss: 0.0235
# Epoch 25/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0097 - val_loss: 0.0235
# Epoch 26/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0096 - val_loss: 0.0234
# Epoch 27/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0095 - val_loss: 0.0233
# Epoch 28/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0093 - val_loss: 0.0235
# Epoch 29/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0093 - val_loss: 0.0234
# Epoch 30/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0093 - val_loss: 0.0235
# Epoch 31/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0093 - val_loss: 0.0233
# Epoch 32/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0091 - val_loss: 0.0235
# Epoch 33/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0091 - val_loss: 0.0236
# Epoch 34/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0090 - val_loss: 0.0236
# Epoch 35/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0090 - val_loss: 0.0237
# Epoch 36/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0089 - val_loss: 0.0238
# Epoch 37/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0089 - val_loss: 0.0235
# Epoch 38/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0089 - val_loss: 0.0235
# Epoch 39/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0089 - val_loss: 0.0234
# Epoch 40/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0087 - val_loss: 0.0234
# Epoch 41/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0087 - val_loss: 0.0233
# Epoch 42/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0087 - val_loss: 0.0235
# Epoch 43/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0088 - val_loss: 0.0233
# Epoch 44/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0086 - val_loss: 0.0232
# Epoch 45/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0086 - val_loss: 0.0235
# Epoch 46/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0086 - val_loss: 0.0234
# Epoch 47/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0086 - val_loss: 0.0234
# Epoch 48/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0235
# Epoch 49/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 50/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0233
# Epoch 51/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 52/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 53/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 54/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 55/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 56/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0231
# Epoch 57/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 58/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 59/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0232
# Epoch 60/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 61/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0233
# Epoch 62/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 63/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0236
# Epoch 64/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 65/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0083 - val_loss: 0.0235
# Epoch 66/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 67/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 68/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 69/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0234
# Epoch 70/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0235
# Epoch 71/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0083 - val_loss: 0.0235
# Epoch 72/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 73/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0083 - val_loss: 0.0235
# Epoch 74/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0082 - val_loss: 0.0237
# Epoch 75/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0235
# Epoch 76/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0082 - val_loss: 0.0238
# Epoch 77/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 78/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0082 - val_loss: 0.0236
# Epoch 79/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0082 - val_loss: 0.0239
# Epoch 80/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0082 - val_loss: 0.0238
# Epoch 81/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0082 - val_loss: 0.0237
# Stacked LSTM:
# Mean Absolute Error: 1.13
# Root Mean Square Error: 1.82

# %% [markdown]
# ## **Single layer 16 neurons**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(1255)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
#df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
#df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 16, input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))

  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(GRU)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False, callbacks = [early_stop])
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 16)                960
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 977
# Trainable params: 977
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 5s 7ms/step - loss: 0.0414 - val_loss: 0.0275
# Epoch 2/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0159 - val_loss: 0.0241
# Epoch 3/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0144 - val_loss: 0.0232
# Epoch 4/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0138 - val_loss: 0.0232
# Epoch 5/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0130 - val_loss: 0.0235
# Epoch 6/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0128 - val_loss: 0.0234
# Epoch 7/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0126 - val_loss: 0.0237
# Epoch 8/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0124 - val_loss: 0.0235
# Epoch 9/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0122 - val_loss: 0.0240
# Epoch 10/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0122 - val_loss: 0.0230
# Epoch 11/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0120 - val_loss: 0.0236
# Epoch 12/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0119 - val_loss: 0.0237
# Epoch 13/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0119 - val_loss: 0.0235
# Epoch 14/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0117 - val_loss: 0.0237
# Epoch 15/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0114 - val_loss: 0.0233
# Epoch 16/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0111 - val_loss: 0.0235
# Epoch 17/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0110 - val_loss: 0.0231
# Epoch 18/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0233
# Epoch 19/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0106 - val_loss: 0.0234
# Epoch 20/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0106 - val_loss: 0.0233
# Epoch 21/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0104 - val_loss: 0.0233
# Epoch 22/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0103 - val_loss: 0.0232
# Epoch 23/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0102 - val_loss: 0.0232
# Epoch 24/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0101 - val_loss: 0.0232
# Epoch 25/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0101 - val_loss: 0.0232
# Epoch 26/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0100 - val_loss: 0.0233
# Epoch 27/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0098 - val_loss: 0.0233
# Epoch 28/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0099 - val_loss: 0.0233
# Epoch 29/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0099 - val_loss: 0.0233
# Epoch 30/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0098 - val_loss: 0.0235
# Epoch 31/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0098 - val_loss: 0.0233
# Epoch 32/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0097 - val_loss: 0.0236
# Epoch 33/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0097 - val_loss: 0.0234
# Epoch 34/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0097 - val_loss: 0.0235
# Epoch 35/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0097 - val_loss: 0.0232
# Stacked LSTM:
# Mean Absolute Error: 1.17
# Root Mean Square Error: 1.86

# %% [markdown]
# ## **Single layer 8 neurons**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(1278)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
df.isnull().sum(axis = 0)
# Out:
# Speed (m/s)    0
# Direction      0
# Energy         0
# dtype: int64

# %%
#df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
#df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)

# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 8, input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))

  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.0001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(GRU)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False, callbacks = [early_stop])
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 8)                 288
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 297
# Trainable params: 297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 5s 7ms/step - loss: 0.0614 - val_loss: 0.0397
# Epoch 2/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0482 - val_loss: 0.0368
# Epoch 3/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0422 - val_loss: 0.0346
# Epoch 4/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0376 - val_loss: 0.0329
# Epoch 5/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0331 - val_loss: 0.0316
# Epoch 6/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0291 - val_loss: 0.0302
# Epoch 7/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0260 - val_loss: 0.0295
# Epoch 8/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0233 - val_loss: 0.0288
# Epoch 9/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0214 - val_loss: 0.0285
# Epoch 10/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0199 - val_loss: 0.0286
# Epoch 11/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0190 - val_loss: 0.0282
# Epoch 12/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0185 - val_loss: 0.0279
# Epoch 13/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0178 - val_loss: 0.0278
# Epoch 14/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0176 - val_loss: 0.0283
# Epoch 15/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0174 - val_loss: 0.0282
# Epoch 16/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0174 - val_loss: 0.0281
# Epoch 17/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0168 - val_loss: 0.0280
# Epoch 18/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0169 - val_loss: 0.0277
# Epoch 19/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0165 - val_loss: 0.0279
# Epoch 20/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0165 - val_loss: 0.0278
# Epoch 21/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0163 - val_loss: 0.0279
# Epoch 22/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0161 - val_loss: 0.0280
# Epoch 23/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0159 - val_loss: 0.0277
# Epoch 24/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0157 - val_loss: 0.0276
# Epoch 25/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0158 - val_loss: 0.0278
# Epoch 26/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0157 - val_loss: 0.0275
# Epoch 27/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0155 - val_loss: 0.0277
# Epoch 28/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0154 - val_loss: 0.0275
# Epoch 29/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0156 - val_loss: 0.0276
# Epoch 30/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0151 - val_loss: 0.0275
# Epoch 31/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0150 - val_loss: 0.0275
# Epoch 32/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0151 - val_loss: 0.0274
# Epoch 33/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0154 - val_loss: 0.0272
# Epoch 34/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0151 - val_loss: 0.0277
# Epoch 35/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0148 - val_loss: 0.0272
# Epoch 36/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0148 - val_loss: 0.0272
# Epoch 37/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0145 - val_loss: 0.0273
# Epoch 38/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0146 - val_loss: 0.0273
# Epoch 39/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0145 - val_loss: 0.0273
# Epoch 40/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0144 - val_loss: 0.0273
# Epoch 41/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0143 - val_loss: 0.0274
# Epoch 42/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0144 - val_loss: 0.0273
# Epoch 43/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0144 - val_loss: 0.0273
# Epoch 44/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0145 - val_loss: 0.0271
# Epoch 45/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0143 - val_loss: 0.0275
# Epoch 46/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0141 - val_loss: 0.0273
# Epoch 47/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0141 - val_loss: 0.0272
# Epoch 48/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0140 - val_loss: 0.0275
# Epoch 49/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0140 - val_loss: 0.0272
# Epoch 50/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0141 - val_loss: 0.0272
# Epoch 51/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0142 - val_loss: 0.0272
# Epoch 52/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0139 - val_loss: 0.0273
# Epoch 53/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0140 - val_loss: 0.0273
# Epoch 54/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0140 - val_loss: 0.0273
# Epoch 55/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0140 - val_loss: 0.0272
# Epoch 56/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0138 - val_loss: 0.0272
# Epoch 57/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0137 - val_loss: 0.0271
# Epoch 58/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0139 - val_loss: 0.0268
# Epoch 59/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0138 - val_loss: 0.0268
# Epoch 60/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0139 - val_loss: 0.0271
# Epoch 61/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0137 - val_loss: 0.0271
# Epoch 62/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0137 - val_loss: 0.0274
# Epoch 63/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0136 - val_loss: 0.0270
# Epoch 64/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0136 - val_loss: 0.0271
# Epoch 65/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0136 - val_loss: 0.0271
# Epoch 66/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0136 - val_loss: 0.0271
# Epoch 67/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0137 - val_loss: 0.0270
# Epoch 68/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0134 - val_loss: 0.0270
# Epoch 69/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0133 - val_loss: 0.0275
# Epoch 70/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0135 - val_loss: 0.0272
# Epoch 71/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0136 - val_loss: 0.0273
# Epoch 72/100
# 460/460 [==============================] - 3s 7ms/step - loss: 0.0137 - val_loss: 0.0272
# Epoch 73/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0134 - val_loss: 0.0271
# Epoch 74/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0133 - val_loss: 0.0271
# Epoch 75/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0132 - val_loss: 0.0272
# Epoch 76/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0135 - val_loss: 0.0270
# Epoch 77/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0134 - val_loss: 0.0271
# Epoch 78/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0134 - val_loss: 0.0272
# Epoch 79/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0134 - val_loss: 0.0271
# Epoch 80/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0134 - val_loss: 0.0270
# Epoch 81/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0133 - val_loss: 0.0269
# Epoch 82/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0133 - val_loss: 0.0272
# Epoch 83/100
# 460/460 [==============================] - 3s 6ms/step - loss: 0.0134 - val_loss: 0.0269
# Stacked LSTM:
# Mean Absolute Error: 1.45
# Root Mean Square Error: 2.09
