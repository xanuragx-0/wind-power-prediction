# %% [markdown]
# <a href="https://colab.research.google.com/github/xanuragx-0/wind-power-prediction/blob/main/Stacked_LSTM_3Layers_WP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import  Sequential,layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

from pandas.plotting import register_matplotlib_converters
import seaborn as sns

from datetime import datetime
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# ### **16-16-16**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(145)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 16, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 16, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 16))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  #history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)
#validation_data=(X_test,y_test)
# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)

#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)


def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM 3 LAYERS')
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 16)            1216
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 16)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 16)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 5,457
# Trainable params: 5,457
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 13s 18ms/step - loss: 0.0379 - val_loss: 0.0321
# Epoch 2/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0250 - val_loss: 0.0298
# Epoch 3/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0226 - val_loss: 0.0278
# Epoch 4/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0201 - val_loss: 0.0264
# Epoch 5/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0179 - val_loss: 0.0261
# Epoch 6/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0166 - val_loss: 0.0242
# Epoch 7/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0150 - val_loss: 0.0235
# Epoch 8/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0138 - val_loss: 0.0233
# Epoch 9/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0128 - val_loss: 0.0230
# Epoch 10/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0116 - val_loss: 0.0234
# Epoch 11/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0111 - val_loss: 0.0235
# Epoch 12/100
# 454/454 [==============================] - 8s 17ms/step - loss: 0.0104 - val_loss: 0.0236
# Epoch 13/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0101 - val_loss: 0.0235
# Epoch 14/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0100 - val_loss: 0.0232
# Epoch 15/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0098 - val_loss: 0.0241
# Epoch 16/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0237
# Epoch 17/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0234
# Epoch 18/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0239
# Epoch 19/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0092 - val_loss: 0.0240
# Epoch 20/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0092 - val_loss: 0.0239
# Epoch 21/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0091 - val_loss: 0.0238
# Epoch 22/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0090 - val_loss: 0.0247
# Epoch 23/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0090 - val_loss: 0.0244
# Epoch 24/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0091 - val_loss: 0.0241
# Epoch 25/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0091 - val_loss: 0.0239
# Epoch 26/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0090 - val_loss: 0.0250
# Epoch 27/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0088 - val_loss: 0.0247
# Epoch 28/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0089 - val_loss: 0.0238
# Epoch 29/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0089 - val_loss: 0.0238
# Epoch 30/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0088 - val_loss: 0.0245
# Epoch 31/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0088 - val_loss: 0.0243
# Epoch 32/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0088 - val_loss: 0.0247
# Epoch 33/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0244
# Epoch 34/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0246
# Epoch 35/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0088 - val_loss: 0.0249
# Epoch 36/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0241
# Epoch 37/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0241
# Epoch 38/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0243
# Epoch 39/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0241
# Epoch 40/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0086 - val_loss: 0.0241
# Epoch 41/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0241
# Epoch 42/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0086 - val_loss: 0.0243
# Epoch 43/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0244
# Epoch 44/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0244
# Epoch 45/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0087 - val_loss: 0.0247
# Epoch 46/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0242
# Epoch 47/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0241
# Epoch 48/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0242
# Epoch 49/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0086 - val_loss: 0.0240
# Epoch 50/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0086 - val_loss: 0.0238
# Epoch 51/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0086 - val_loss: 0.0240
# Epoch 52/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0240
# Epoch 53/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0242
# Epoch 54/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0239
# Epoch 55/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0241
# Epoch 56/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0241
# Epoch 57/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0240
# Epoch 58/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0239
# Epoch 59/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0238
# Epoch 60/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0240
# Epoch 61/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0237
# Epoch 62/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0241
# Epoch 63/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0235
# Epoch 64/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0238
# Epoch 65/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0238
# Epoch 66/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0236
# Epoch 67/100
# 454/454 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 68/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0239
# Epoch 69/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0239
# Epoch 70/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0235
# Epoch 71/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0236
# Epoch 72/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0238
# Epoch 73/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0082 - val_loss: 0.0238
# Epoch 74/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0239
# Epoch 75/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 76/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0241
# Epoch 77/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 78/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0085 - val_loss: 0.0242
# Epoch 79/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 80/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 81/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 82/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 83/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0236
# Epoch 84/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0236
# Epoch 85/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0235
# Epoch 86/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0082 - val_loss: 0.0237
# Epoch 87/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0240
# Epoch 88/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 89/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0236
# Epoch 90/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 91/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0238
# Epoch 92/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0240
# Epoch 93/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0239
# Epoch 94/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0240
# Epoch 95/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0084 - val_loss: 0.0242
# Epoch 96/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0242
# Epoch 97/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0082 - val_loss: 0.0241
# Epoch 98/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 99/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 100/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0083 - val_loss: 0.0239
# Stacked LSTM 3 LAYERS:
# Mean Absolute Error: 1.10
# Root Mean Square Error: 1.83

# %% [markdown]
# ### **32-32-32**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(123)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 32, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 32, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 32))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 32)            4480
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 32)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 32)            8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 21,153
# Trainable params: 21,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 14s 21ms/step - loss: 0.0306 - val_loss: 0.0321
# Epoch 2/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0236 - val_loss: 0.0293
# Epoch 3/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0204 - val_loss: 0.0269
# Epoch 4/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0178 - val_loss: 0.0246
# Epoch 5/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0156 - val_loss: 0.0235
# Epoch 6/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0144 - val_loss: 0.0234
# Epoch 7/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0132 - val_loss: 0.0238
# Epoch 8/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0122 - val_loss: 0.0242
# Epoch 9/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0108 - val_loss: 0.0246
# Epoch 10/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0100 - val_loss: 0.0264
# Epoch 11/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0094 - val_loss: 0.0257
# Epoch 12/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0092 - val_loss: 0.0264
# Epoch 13/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0091 - val_loss: 0.0258
# Epoch 14/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0089 - val_loss: 0.0260
# Epoch 15/100
# 454/454 [==============================] - 8s 19ms/step - loss: 0.0087 - val_loss: 0.0267
# Epoch 16/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0264
# Epoch 17/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0269
# Epoch 18/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0087 - val_loss: 0.0268
# Epoch 19/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0269
# Epoch 20/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0266
# Epoch 21/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0085 - val_loss: 0.0256
# Epoch 22/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0262
# Epoch 23/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0261
# Epoch 24/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0268
# Epoch 25/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0083 - val_loss: 0.0269
# Epoch 26/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0262
# Epoch 27/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0258
# Epoch 28/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0260
# Epoch 29/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0255
# Epoch 30/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0083 - val_loss: 0.0257
# Epoch 31/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0083 - val_loss: 0.0254
# Epoch 32/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0082 - val_loss: 0.0253
# Epoch 33/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0082 - val_loss: 0.0254
# Epoch 34/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0082 - val_loss: 0.0254
# Epoch 35/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0082 - val_loss: 0.0249
# Epoch 36/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0082 - val_loss: 0.0246
# Epoch 37/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0253
# Epoch 38/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0249
# Epoch 39/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0250
# Epoch 40/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0249
# Epoch 41/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0082 - val_loss: 0.0248
# Epoch 42/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0248
# Epoch 43/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0250
# Epoch 44/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0250
# Epoch 45/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0249
# Epoch 46/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0245
# Epoch 47/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0245
# Epoch 48/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0243
# Epoch 49/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0244
# Epoch 50/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0245
# Epoch 51/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0243
# Epoch 52/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0242
# Epoch 53/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0241
# Epoch 54/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0244
# Epoch 55/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0245
# Epoch 56/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0243
# Epoch 57/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0240
# Epoch 58/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0245
# Epoch 59/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0242
# Epoch 60/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0242
# Epoch 61/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0243
# Epoch 62/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0242
# Epoch 63/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0240
# Epoch 64/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0242
# Epoch 65/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0238
# Epoch 66/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0241
# Epoch 67/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0242
# Epoch 68/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0243
# Epoch 69/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0241
# Epoch 70/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0242
# Epoch 71/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0240
# Epoch 72/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0239
# Epoch 73/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0237
# Epoch 74/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0239
# Epoch 75/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0237
# Epoch 76/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0238
# Epoch 77/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0239
# Epoch 78/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0239
# Epoch 79/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0237
# Epoch 80/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0236
# Epoch 81/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0237
# Epoch 82/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0236
# Epoch 83/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0237
# Epoch 84/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0239
# Epoch 85/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0238
# Epoch 86/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0238
# Epoch 87/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0078 - val_loss: 0.0238
# Epoch 88/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0237
# Epoch 89/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0238
# Epoch 90/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0237
# Epoch 91/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0078 - val_loss: 0.0234
# Epoch 92/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0239
# Epoch 93/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0237
# Epoch 94/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0236
# Epoch 95/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0237
# Epoch 96/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0078 - val_loss: 0.0237
# Epoch 97/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0078 - val_loss: 0.0238
# Epoch 98/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0077 - val_loss: 0.0238
# Epoch 99/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0238
# Epoch 100/100
# 454/454 [==============================] - 9s 19ms/step - loss: 0.0077 - val_loss: 0.0238
# Stacked LSTM:
# Mean Absolute Error: 1.12
# Root Mean Square Error: 1.83

# %% [markdown]
# ### **8-8-8**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(333)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)
# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 8, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 8, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 8))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  #history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)

#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 8)             352
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 8)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 8)             544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 8)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 8)                 544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,449
# Trainable params: 1,449
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 12s 17ms/step - loss: 0.0438 - val_loss: 0.0321
# Epoch 2/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0268 - val_loss: 0.0306
# Epoch 3/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0250 - val_loss: 0.0298
# Epoch 4/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0232 - val_loss: 0.0291
# Epoch 5/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0216 - val_loss: 0.0279
# Epoch 6/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0196 - val_loss: 0.0273
# Epoch 7/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0186 - val_loss: 0.0269
# Epoch 8/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0173 - val_loss: 0.0251
# Epoch 9/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0167 - val_loss: 0.0258
# Epoch 10/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0157 - val_loss: 0.0248
# Epoch 11/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0147 - val_loss: 0.0243
# Epoch 12/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0142 - val_loss: 0.0238
# Epoch 13/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0134 - val_loss: 0.0240
# Epoch 14/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0127 - val_loss: 0.0235
# Epoch 15/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0122 - val_loss: 0.0234
# Epoch 16/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0119 - val_loss: 0.0240
# Epoch 17/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0115 - val_loss: 0.0235
# Epoch 18/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0112 - val_loss: 0.0235
# Epoch 19/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0108 - val_loss: 0.0243
# Epoch 20/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0107 - val_loss: 0.0236
# Epoch 21/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0105 - val_loss: 0.0232
# Epoch 22/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0104 - val_loss: 0.0239
# Epoch 23/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0103 - val_loss: 0.0239
# Epoch 24/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0102 - val_loss: 0.0241
# Epoch 25/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0101 - val_loss: 0.0237
# Epoch 26/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0101 - val_loss: 0.0238
# Epoch 27/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0100 - val_loss: 0.0235
# Epoch 28/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0238
# Epoch 29/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0098 - val_loss: 0.0241
# Epoch 30/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0098 - val_loss: 0.0239
# Epoch 31/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0242
# Epoch 32/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0239
# Epoch 33/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0099 - val_loss: 0.0240
# Epoch 34/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0098 - val_loss: 0.0240
# Epoch 35/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0244
# Epoch 36/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0237
# Epoch 37/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0241
# Epoch 38/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0242
# Epoch 39/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0097 - val_loss: 0.0239
# Epoch 40/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0095 - val_loss: 0.0240
# Epoch 41/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0098 - val_loss: 0.0245
# Epoch 42/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0243
# Epoch 43/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0242
# Epoch 44/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0235
# Epoch 45/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0238
# Epoch 46/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0240
# Epoch 47/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0243
# Epoch 48/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0238
# Epoch 49/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0095 - val_loss: 0.0240
# Epoch 50/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0240
# Epoch 51/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0240
# Epoch 52/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0241
# Epoch 53/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0241
# Epoch 54/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0096 - val_loss: 0.0236
# Epoch 55/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0241
# Epoch 56/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0244
# Epoch 57/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0236
# Epoch 58/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0243
# Epoch 59/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0241
# Epoch 60/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0242
# Epoch 61/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0237
# Epoch 62/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0237
# Epoch 63/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0236
# Epoch 64/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0238
# Epoch 65/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0237
# Epoch 66/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0242
# Epoch 67/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0232
# Epoch 68/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0239
# Epoch 69/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0236
# Epoch 70/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0092 - val_loss: 0.0239
# Epoch 71/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0232
# Epoch 72/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0236
# Epoch 73/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0238
# Epoch 74/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0094 - val_loss: 0.0236
# Epoch 75/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0239
# Epoch 76/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0235
# Epoch 77/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0233
# Epoch 78/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0240
# Epoch 79/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0094 - val_loss: 0.0237
# Epoch 80/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0235
# Epoch 81/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0238
# Epoch 82/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0241
# Epoch 83/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0093 - val_loss: 0.0237
# Epoch 84/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0093 - val_loss: 0.0238
# Epoch 85/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0234
# Epoch 86/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0092 - val_loss: 0.0234
# Epoch 87/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0092 - val_loss: 0.0235
# Epoch 88/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0236
# Epoch 89/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0092 - val_loss: 0.0232
# Epoch 90/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0235
# Epoch 91/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0239
# Epoch 92/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0236
# Epoch 93/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0232
# Epoch 94/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0238
# Epoch 95/100
# 454/454 [==============================] - 7s 15ms/step - loss: 0.0095 - val_loss: 0.0238
# Epoch 96/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0092 - val_loss: 0.0239
# Epoch 97/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0238
# Epoch 98/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0238
# Epoch 99/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0235
# Epoch 100/100
# 454/454 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0238
# Stacked LSTM:
# Mean Absolute Error: 1.11
# Root Mean Square Error: 1.83

# %% [markdown]
# ### **With Preprocessing**

# %% [markdown]
# ### **32-32-32**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(23)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
#df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)

# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 32, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 32, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 32))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 32)            4480
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 32)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 32)            8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 21,153
# Trainable params: 21,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 15s 22ms/step - loss: 0.0311 - val_loss: 0.0309
# Epoch 2/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0224 - val_loss: 0.0290
# Epoch 3/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0192 - val_loss: 0.0266
# Epoch 4/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0160 - val_loss: 0.0255
# Epoch 5/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0137 - val_loss: 0.0267
# Epoch 6/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0116 - val_loss: 0.0265
# Epoch 7/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0107 - val_loss: 0.0262
# Epoch 8/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0099 - val_loss: 0.0270
# Epoch 9/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0267
# Epoch 10/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0093 - val_loss: 0.0268
# Epoch 11/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0091 - val_loss: 0.0272
# Epoch 12/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0089 - val_loss: 0.0280
# Epoch 13/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0088 - val_loss: 0.0278
# Epoch 14/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0087 - val_loss: 0.0287
# Epoch 15/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0291
# Epoch 16/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0085 - val_loss: 0.0281
# Epoch 17/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0295
# Epoch 18/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0296
# Epoch 19/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0297
# Epoch 20/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0282
# Epoch 21/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0288
# Epoch 22/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0285
# Epoch 23/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0083 - val_loss: 0.0286
# Epoch 24/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0083 - val_loss: 0.0293
# Epoch 25/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0083 - val_loss: 0.0283
# Epoch 26/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0284
# Epoch 27/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0082 - val_loss: 0.0278
# Epoch 28/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0083 - val_loss: 0.0283
# Epoch 29/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0082 - val_loss: 0.0281
# Epoch 30/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0083 - val_loss: 0.0280
# Epoch 31/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0083 - val_loss: 0.0275
# Epoch 32/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0082 - val_loss: 0.0281
# Epoch 33/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0082 - val_loss: 0.0270
# Epoch 34/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0082 - val_loss: 0.0274
# Epoch 35/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0081 - val_loss: 0.0274
# Epoch 36/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0081 - val_loss: 0.0277
# Epoch 37/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0082 - val_loss: 0.0273
# Epoch 38/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0081 - val_loss: 0.0269
# Epoch 39/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0268
# Epoch 40/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0081 - val_loss: 0.0269
# Epoch 41/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0081 - val_loss: 0.0269
# Epoch 42/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0269
# Epoch 43/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0267
# Epoch 44/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0266
# Epoch 45/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0081 - val_loss: 0.0266
# Epoch 46/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0080 - val_loss: 0.0265
# Epoch 47/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0080 - val_loss: 0.0263
# Epoch 48/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0263
# Epoch 49/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0267
# Epoch 50/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0263
# Epoch 51/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0262
# Epoch 52/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0080 - val_loss: 0.0263
# Epoch 53/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0262
# Epoch 54/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0262
# Epoch 55/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0080 - val_loss: 0.0261
# Epoch 56/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0258
# Epoch 57/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0080 - val_loss: 0.0261
# Epoch 58/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0258
# Epoch 59/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0078 - val_loss: 0.0256
# Epoch 60/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0262
# Epoch 61/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0262
# Epoch 62/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0253
# Epoch 63/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0079 - val_loss: 0.0258
# Epoch 64/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0259
# Epoch 65/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0256
# Epoch 66/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0078 - val_loss: 0.0254
# Epoch 67/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0256
# Epoch 68/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0256
# Epoch 69/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0078 - val_loss: 0.0256
# Epoch 70/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0079 - val_loss: 0.0255
# Epoch 71/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0255
# Epoch 72/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0252
# Epoch 73/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0078 - val_loss: 0.0252
# Epoch 74/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0077 - val_loss: 0.0256
# Epoch 75/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0252
# Epoch 76/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0251
# Epoch 77/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0251
# Epoch 78/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0251
# Epoch 79/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0250
# Epoch 80/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0249
# Epoch 81/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0247
# Epoch 82/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0254
# Epoch 83/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0248
# Epoch 84/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0249
# Epoch 85/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0248
# Epoch 86/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0247
# Epoch 87/100
# 460/460 [==============================] - 10s 21ms/step - loss: 0.0077 - val_loss: 0.0249
# Epoch 88/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0249
# Epoch 89/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0076 - val_loss: 0.0246
# Epoch 90/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0247
# Epoch 91/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0078 - val_loss: 0.0244
# Epoch 92/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0247
# Epoch 93/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0247
# Epoch 94/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0076 - val_loss: 0.0248
# Epoch 95/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0248
# Epoch 96/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0249
# Epoch 97/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0076 - val_loss: 0.0247
# Epoch 98/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0244
# Epoch 99/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0077 - val_loss: 0.0244
# Epoch 100/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0076 - val_loss: 0.0246
# Stacked LSTM:
# Mean Absolute Error: 1.13
# Root Mean Square Error: 1.81

# %% [markdown]
# ### **16-16-16**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(322)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
#df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)

# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 16, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 16, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 16))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  #history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)

#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)


def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM 3 LAYERS')
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 16)            1216
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 16)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 16)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 5,457
# Trainable params: 5,457
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 13s 18ms/step - loss: 0.0367 - val_loss: 0.0343
# Epoch 2/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0249 - val_loss: 0.0308
# Epoch 3/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0222 - val_loss: 0.0299
# Epoch 4/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0205 - val_loss: 0.0297
# Epoch 5/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0185 - val_loss: 0.0281
# Epoch 6/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0166 - val_loss: 0.0258
# Epoch 7/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0145 - val_loss: 0.0259
# Epoch 8/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0129 - val_loss: 0.0257
# Epoch 9/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0117 - val_loss: 0.0260
# Epoch 10/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0111 - val_loss: 0.0255
# Epoch 11/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0105 - val_loss: 0.0258
# Epoch 12/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0100 - val_loss: 0.0262
# Epoch 13/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0098 - val_loss: 0.0264
# Epoch 14/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0096 - val_loss: 0.0253
# Epoch 15/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0095 - val_loss: 0.0262
# Epoch 16/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0261
# Epoch 17/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0260
# Epoch 18/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0092 - val_loss: 0.0257
# Epoch 19/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0091 - val_loss: 0.0262
# Epoch 20/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0092 - val_loss: 0.0264
# Epoch 21/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0091 - val_loss: 0.0262
# Epoch 22/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0091 - val_loss: 0.0259
# Epoch 23/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0090 - val_loss: 0.0255
# Epoch 24/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0090 - val_loss: 0.0258
# Epoch 25/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0090 - val_loss: 0.0263
# Epoch 26/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0089 - val_loss: 0.0257
# Epoch 27/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0090 - val_loss: 0.0259
# Epoch 28/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0089 - val_loss: 0.0258
# Epoch 29/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0088 - val_loss: 0.0260
# Epoch 30/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0089 - val_loss: 0.0255
# Epoch 31/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0089 - val_loss: 0.0255
# Epoch 32/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0088 - val_loss: 0.0251
# Epoch 33/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0088 - val_loss: 0.0260
# Epoch 34/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0088 - val_loss: 0.0258
# Epoch 35/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0088 - val_loss: 0.0262
# Epoch 36/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0088 - val_loss: 0.0255
# Epoch 37/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0088 - val_loss: 0.0258
# Epoch 38/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0088 - val_loss: 0.0259
# Epoch 39/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0086 - val_loss: 0.0257
# Epoch 40/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0087 - val_loss: 0.0254
# Epoch 41/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0087 - val_loss: 0.0251
# Epoch 42/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0088 - val_loss: 0.0259
# Epoch 43/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0086 - val_loss: 0.0253
# Epoch 44/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0087 - val_loss: 0.0255
# Epoch 45/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0086 - val_loss: 0.0253
# Epoch 46/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0086 - val_loss: 0.0254
# Epoch 47/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0086 - val_loss: 0.0253
# Epoch 48/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0086 - val_loss: 0.0259
# Epoch 49/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0087 - val_loss: 0.0255
# Epoch 50/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0253
# Epoch 51/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0086 - val_loss: 0.0251
# Epoch 52/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0086 - val_loss: 0.0252
# Epoch 53/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0248
# Epoch 54/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0086 - val_loss: 0.0250
# Epoch 55/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0085 - val_loss: 0.0248
# Epoch 56/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0086 - val_loss: 0.0245
# Epoch 57/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0257
# Epoch 58/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0253
# Epoch 59/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0248
# Epoch 60/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0248
# Epoch 61/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0246
# Epoch 62/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0251
# Epoch 63/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0246
# Epoch 64/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0085 - val_loss: 0.0244
# Epoch 65/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0249
# Epoch 66/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0249
# Epoch 67/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0247
# Epoch 68/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0248
# Epoch 69/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0248
# Epoch 70/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0246
# Epoch 71/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0248
# Epoch 72/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0244
# Epoch 73/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0242
# Epoch 74/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0244
# Epoch 75/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0248
# Epoch 76/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0247
# Epoch 77/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0084 - val_loss: 0.0241
# Epoch 78/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0084 - val_loss: 0.0245
# Epoch 79/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0084 - val_loss: 0.0243
# Epoch 80/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0248
# Epoch 81/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0249
# Epoch 82/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0083 - val_loss: 0.0245
# Epoch 83/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0245
# Epoch 84/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0246
# Epoch 85/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0247
# Epoch 86/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0246
# Epoch 87/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0083 - val_loss: 0.0245
# Epoch 88/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0248
# Epoch 89/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0246
# Epoch 90/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0243
# Epoch 91/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0082 - val_loss: 0.0243
# Epoch 92/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0082 - val_loss: 0.0248
# Epoch 93/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0084 - val_loss: 0.0242
# Epoch 94/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0245
# Epoch 95/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0243
# Epoch 96/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0082 - val_loss: 0.0245
# Epoch 97/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0082 - val_loss: 0.0247
# Epoch 98/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0082 - val_loss: 0.0244
# Epoch 99/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0241
# Epoch 100/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0083 - val_loss: 0.0243
# Stacked LSTM 3 LAYERS:
# Mean Absolute Error: 1.10
# Root Mean Square Error: 1.81

# %% [markdown]
# ### **8-8-8**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(444)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
#df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)

# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)
# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 8, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 8, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 8))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  #history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)

#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 8)             352
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 8)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 8)             544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 8)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 8)                 544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,449
# Trainable params: 1,449
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 13s 19ms/step - loss: 0.0404 - val_loss: 0.0337
# Epoch 2/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0265 - val_loss: 0.0313
# Epoch 3/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0238 - val_loss: 0.0304
# Epoch 4/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0213 - val_loss: 0.0289
# Epoch 5/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0193 - val_loss: 0.0277
# Epoch 6/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0178 - val_loss: 0.0272
# Epoch 7/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0164 - val_loss: 0.0260
# Epoch 8/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0152 - val_loss: 0.0258
# Epoch 9/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0141 - val_loss: 0.0256
# Epoch 10/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0135 - val_loss: 0.0252
# Epoch 11/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0129 - val_loss: 0.0249
# Epoch 12/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0123 - val_loss: 0.0255
# Epoch 13/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0119 - val_loss: 0.0256
# Epoch 14/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0117 - val_loss: 0.0251
# Epoch 15/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0111 - val_loss: 0.0252
# Epoch 16/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0110 - val_loss: 0.0250
# Epoch 17/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0109 - val_loss: 0.0252
# Epoch 18/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0106 - val_loss: 0.0250
# Epoch 19/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0105 - val_loss: 0.0256
# Epoch 20/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0105 - val_loss: 0.0250
# Epoch 21/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0103 - val_loss: 0.0252
# Epoch 22/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0103 - val_loss: 0.0251
# Epoch 23/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0101 - val_loss: 0.0252
# Epoch 24/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0102 - val_loss: 0.0255
# Epoch 25/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0100 - val_loss: 0.0252
# Epoch 26/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0102 - val_loss: 0.0253
# Epoch 27/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0100 - val_loss: 0.0255
# Epoch 28/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0100 - val_loss: 0.0252
# Epoch 29/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0253
# Epoch 30/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0100 - val_loss: 0.0254
# Epoch 31/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0258
# Epoch 32/100
# 460/460 [==============================] - 7s 15ms/step - loss: 0.0098 - val_loss: 0.0249
# Epoch 33/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0252
# Epoch 34/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0254
# Epoch 35/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0100 - val_loss: 0.0251
# Epoch 36/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0098 - val_loss: 0.0253
# Epoch 37/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0250
# Epoch 38/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0099 - val_loss: 0.0251
# Epoch 39/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0255
# Epoch 40/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0252
# Epoch 41/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0098 - val_loss: 0.0253
# Epoch 42/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0097 - val_loss: 0.0253
# Epoch 43/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0097 - val_loss: 0.0250
# Epoch 44/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0096 - val_loss: 0.0250
# Epoch 45/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0096 - val_loss: 0.0255
# Epoch 46/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0098 - val_loss: 0.0249
# Epoch 47/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0097 - val_loss: 0.0257
# Epoch 48/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0097 - val_loss: 0.0251
# Epoch 49/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0098 - val_loss: 0.0250
# Epoch 50/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0096 - val_loss: 0.0247
# Epoch 51/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0095 - val_loss: 0.0254
# Epoch 52/100
# 460/460 [==============================] - 8s 17ms/step - loss: 0.0097 - val_loss: 0.0247
# Epoch 53/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0247
# Epoch 54/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0253
# Epoch 55/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0254
# Epoch 56/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0250
# Epoch 57/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0252
# Epoch 58/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0254
# Epoch 59/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0249
# Epoch 60/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0251
# Epoch 61/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0248
# Epoch 62/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0249
# Epoch 63/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0097 - val_loss: 0.0250
# Epoch 64/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0245
# Epoch 65/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0249
# Epoch 66/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0248
# Epoch 67/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0250
# Epoch 68/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0249
# Epoch 69/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0095 - val_loss: 0.0251
# Epoch 70/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0094 - val_loss: 0.0247
# Epoch 71/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0248
# Epoch 72/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0250
# Epoch 73/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0245
# Epoch 74/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0246
# Epoch 75/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0096 - val_loss: 0.0250
# Epoch 76/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0247
# Epoch 77/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0246
# Epoch 78/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0251
# Epoch 79/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0251
# Epoch 80/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0247
# Epoch 81/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0248
# Epoch 82/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0246
# Epoch 83/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0251
# Epoch 84/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0250
# Epoch 85/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0246
# Epoch 86/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0094 - val_loss: 0.0251
# Epoch 87/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0249
# Epoch 88/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0246
# Epoch 89/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0252
# Epoch 90/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0248
# Epoch 91/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0248
# Epoch 92/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0252
# Epoch 93/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0252
# Epoch 94/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0093 - val_loss: 0.0249
# Epoch 95/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0091 - val_loss: 0.0249
# Epoch 96/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0250
# Epoch 97/100
# 460/460 [==============================] - 8s 16ms/step - loss: 0.0094 - val_loss: 0.0246
# Epoch 98/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0095 - val_loss: 0.0248
# Epoch 99/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0247
# Epoch 100/100
# 460/460 [==============================] - 7s 16ms/step - loss: 0.0094 - val_loss: 0.0249
# Stacked LSTM:
# Mean Absolute Error: 1.09
# Root Mean Square Error: 1.82

# %% [markdown]
# ### **32-32-32-32**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(9)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 32, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 32, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 32, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 32))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 32)            4480
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 32)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 32)            8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 32)            8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 29,473
# Trainable params: 29,473
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 20s 30ms/step - loss: 0.0341 - val_loss: 0.0331
# Epoch 2/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0257 - val_loss: 0.0303
# Epoch 3/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0218 - val_loss: 0.0275
# Epoch 4/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0176 - val_loss: 0.0262
# Epoch 5/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0135 - val_loss: 0.0289
# Epoch 6/100
# 454/454 [==============================] - 11s 25ms/step - loss: 0.0113 - val_loss: 0.0282
# Epoch 7/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0104 - val_loss: 0.0283
# Epoch 8/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0098 - val_loss: 0.0278
# Epoch 9/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0094 - val_loss: 0.0279
# Epoch 10/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0092 - val_loss: 0.0281
# Epoch 11/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0092 - val_loss: 0.0280
# Epoch 12/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0090 - val_loss: 0.0287
# Epoch 13/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0090 - val_loss: 0.0300
# Epoch 14/100
# 454/454 [==============================] - 11s 25ms/step - loss: 0.0090 - val_loss: 0.0288
# Epoch 15/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0088 - val_loss: 0.0290
# Epoch 16/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0090 - val_loss: 0.0297
# Epoch 17/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0088 - val_loss: 0.0295
# Epoch 18/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0087 - val_loss: 0.0288
# Epoch 19/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0086 - val_loss: 0.0285
# Epoch 20/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0087 - val_loss: 0.0293
# Epoch 21/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0086 - val_loss: 0.0293
# Epoch 22/100
# 454/454 [==============================] - 11s 25ms/step - loss: 0.0086 - val_loss: 0.0293
# Epoch 23/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0085 - val_loss: 0.0284
# Epoch 24/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0085 - val_loss: 0.0278
# Epoch 25/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0085 - val_loss: 0.0286
# Epoch 26/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0085 - val_loss: 0.0283
# Epoch 27/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0084 - val_loss: 0.0277
# Epoch 28/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0084 - val_loss: 0.0276
# Epoch 29/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0084 - val_loss: 0.0282
# Epoch 30/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0085 - val_loss: 0.0282
# Epoch 31/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0084 - val_loss: 0.0274
# Epoch 32/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0275
# Epoch 33/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0278
# Epoch 34/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0083 - val_loss: 0.0270
# Epoch 35/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0274
# Epoch 36/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0272
# Epoch 37/100
# 454/454 [==============================] - 11s 25ms/step - loss: 0.0082 - val_loss: 0.0266
# Epoch 38/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0082 - val_loss: 0.0271
# Epoch 39/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0083 - val_loss: 0.0267
# Epoch 40/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0268
# Epoch 41/100
# 454/454 [==============================] - 12s 25ms/step - loss: 0.0081 - val_loss: 0.0269
# Epoch 42/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0265
# Epoch 43/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0261
# Epoch 44/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0262
# Epoch 45/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0264
# Epoch 46/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0265
# Epoch 47/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0082 - val_loss: 0.0261
# Epoch 48/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0262
# Epoch 49/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0255
# Epoch 50/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0259
# Epoch 51/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0260
# Epoch 52/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0259
# Epoch 53/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0257
# Epoch 54/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0258
# Epoch 55/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0256
# Epoch 56/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0256
# Epoch 57/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0257
# Epoch 58/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0256
# Epoch 59/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0256
# Epoch 60/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0255
# Epoch 61/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0253
# Epoch 62/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0255
# Epoch 63/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0252
# Epoch 64/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0258
# Epoch 65/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0081 - val_loss: 0.0253
# Epoch 66/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0254
# Epoch 67/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0252
# Epoch 68/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0079 - val_loss: 0.0256
# Epoch 69/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0079 - val_loss: 0.0256
# Epoch 70/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0255
# Epoch 71/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0079 - val_loss: 0.0253
# Epoch 72/100
# 454/454 [==============================] - 12s 27ms/step - loss: 0.0079 - val_loss: 0.0253
# Epoch 73/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0079 - val_loss: 0.0252
# Epoch 74/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0079 - val_loss: 0.0253
# Epoch 75/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0080 - val_loss: 0.0254
# Epoch 76/100
# 454/454 [==============================] - 12s 27ms/step - loss: 0.0079 - val_loss: 0.0254
# Epoch 77/100
# 454/454 [==============================] - 12s 27ms/step - loss: 0.0079 - val_loss: 0.0254
# Epoch 78/100
# 454/454 [==============================] - 12s 27ms/step - loss: 0.0080 - val_loss: 0.0247
# Epoch 79/100
# 454/454 [==============================] - 12s 27ms/step - loss: 0.0079 - val_loss: 0.0248
# Epoch 80/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0079 - val_loss: 0.0250
# Epoch 81/100
# 454/454 [==============================] - 12s 27ms/step - loss: 0.0078 - val_loss: 0.0246
# Epoch 82/100
# 454/454 [==============================] - 12s 27ms/step - loss: 0.0079 - val_loss: 0.0246
# Epoch 83/100
# 454/454 [==============================] - 12s 27ms/step - loss: 0.0078 - val_loss: 0.0249
# Epoch 84/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0079 - val_loss: 0.0249
# Epoch 85/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0246
# Epoch 86/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0246
# Epoch 87/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0077 - val_loss: 0.0245
# Epoch 88/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0245
# Epoch 89/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0247
# Epoch 90/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0245
# Epoch 91/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0244
# Epoch 92/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0243
# Epoch 93/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0244
# Epoch 94/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0247
# Epoch 95/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0244
# Epoch 96/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0077 - val_loss: 0.0243
# Epoch 97/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0241
# Epoch 98/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0077 - val_loss: 0.0243
# Epoch 99/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0078 - val_loss: 0.0243
# Epoch 100/100
# 454/454 [==============================] - 12s 26ms/step - loss: 0.0077 - val_loss: 0.0241
# Stacked LSTM:
# Mean Absolute Error: 1.13
# Root Mean Square Error: 1.82

# %% [markdown]
# ### **16-16-16-16**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(145)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 16, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 16, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 16, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 16))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  #history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)

#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)


def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM 3 LAYERS')
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 16)            1216
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 16)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 16)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 16)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 7,569
# Trainable params: 7,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 19s 26ms/step - loss: 0.0400 - val_loss: 0.0336
# Epoch 2/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0268 - val_loss: 0.0319
# Epoch 3/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0241 - val_loss: 0.0305
# Epoch 4/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0217 - val_loss: 0.0281
# Epoch 5/100
# 454/454 [==============================] - 10s 23ms/step - loss: 0.0184 - val_loss: 0.0273
# Epoch 6/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0163 - val_loss: 0.0256
# Epoch 7/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0143 - val_loss: 0.0257
# Epoch 8/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0129 - val_loss: 0.0258
# Epoch 9/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0118 - val_loss: 0.0255
# Epoch 10/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0111 - val_loss: 0.0263
# Epoch 11/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0106 - val_loss: 0.0261
# Epoch 12/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0102 - val_loss: 0.0250
# Epoch 13/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0101 - val_loss: 0.0258
# Epoch 14/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0099 - val_loss: 0.0267
# Epoch 15/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0098 - val_loss: 0.0263
# Epoch 16/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0096 - val_loss: 0.0260
# Epoch 17/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0095 - val_loss: 0.0263
# Epoch 18/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0095 - val_loss: 0.0258
# Epoch 19/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0094 - val_loss: 0.0260
# Epoch 20/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0093 - val_loss: 0.0262
# Epoch 21/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0094 - val_loss: 0.0251
# Epoch 22/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0092 - val_loss: 0.0258
# Epoch 23/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0092 - val_loss: 0.0255
# Epoch 24/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0092 - val_loss: 0.0254
# Epoch 25/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0093 - val_loss: 0.0250
# Epoch 26/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0091 - val_loss: 0.0257
# Epoch 27/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0090 - val_loss: 0.0252
# Epoch 28/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0091 - val_loss: 0.0254
# Epoch 29/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0091 - val_loss: 0.0250
# Epoch 30/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0090 - val_loss: 0.0256
# Epoch 31/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0089 - val_loss: 0.0258
# Epoch 32/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0090 - val_loss: 0.0258
# Epoch 33/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0089 - val_loss: 0.0256
# Epoch 34/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0253
# Epoch 35/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0089 - val_loss: 0.0252
# Epoch 36/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0254
# Epoch 37/100
# 454/454 [==============================] - 10s 23ms/step - loss: 0.0089 - val_loss: 0.0256
# Epoch 38/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0089 - val_loss: 0.0250
# Epoch 39/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0089 - val_loss: 0.0250
# Epoch 40/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0248
# Epoch 41/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0248
# Epoch 42/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0250
# Epoch 43/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0252
# Epoch 44/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0253
# Epoch 45/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0253
# Epoch 46/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0248
# Epoch 47/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0247
# Epoch 48/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0243
# Epoch 49/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0252
# Epoch 50/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0248
# Epoch 51/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0248
# Epoch 52/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0247
# Epoch 53/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0251
# Epoch 54/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0246
# Epoch 55/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0247
# Epoch 56/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0249
# Epoch 57/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0248
# Epoch 58/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0245
# Epoch 59/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0247
# Epoch 60/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 61/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0246
# Epoch 62/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 63/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 64/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 65/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 66/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0239
# Epoch 67/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0240
# Epoch 68/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0246
# Epoch 69/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0247
# Epoch 70/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0244
# Epoch 71/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0241
# Epoch 72/100
# 454/454 [==============================] - 10s 23ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 73/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0244
# Epoch 74/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0243
# Epoch 75/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0244
# Epoch 76/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 77/100
# 454/454 [==============================] - 10s 23ms/step - loss: 0.0085 - val_loss: 0.0240
# Epoch 78/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0244
# Epoch 79/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0243
# Epoch 80/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 81/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 82/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0245
# Epoch 83/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0084 - val_loss: 0.0244
# Epoch 84/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0242
# Epoch 85/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0238
# Epoch 86/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0245
# Epoch 87/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0084 - val_loss: 0.0244
# Epoch 88/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0244
# Epoch 89/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0238
# Epoch 90/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0084 - val_loss: 0.0241
# Epoch 91/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0243
# Epoch 92/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0084 - val_loss: 0.0240
# Epoch 93/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0084 - val_loss: 0.0241
# Epoch 94/100
# 454/454 [==============================] - 10s 23ms/step - loss: 0.0084 - val_loss: 0.0241
# Epoch 95/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0084 - val_loss: 0.0242
# Epoch 96/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0239
# Epoch 97/100
# 454/454 [==============================] - 10s 23ms/step - loss: 0.0084 - val_loss: 0.0241
# Epoch 98/100
# 454/454 [==============================] - 10s 23ms/step - loss: 0.0085 - val_loss: 0.0241
# Epoch 99/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0240
# Epoch 100/100
# 454/454 [==============================] - 10s 22ms/step - loss: 0.0085 - val_loss: 0.0240
# Stacked LSTM 3 LAYERS:
# Mean Absolute Error: 1.10
# Root Mean Square Error: 1.82

# %% [markdown]
# ### **8-8-8-8**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(333)
df = pd.read_csv('WP.csv',index_col=0,parse_dates=True)
#df.fillna(df.mean(), inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)
# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 8, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 8, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 8, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 8))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  #history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)

#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Out:
# Dimension of train data:  (36268, 3)
# Dimension of test data:  (15544, 3)
# (36268, 2)
# (36268, 1)
# (15544, 2)
# (15544, 1)
# X_train.shape:  (36259, 10, 2)
# y_train.shape:  (36259, 1)
# X_test.shape:  (15535, 10, 2)
# y_test.shape:  (15535, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 8)             352
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 8)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 8)             544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 8)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 8)             544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 8)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 8)                 544
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,993
# Trainable params: 1,993
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 454/454 [==============================] - 17s 24ms/step - loss: 0.0446 - val_loss: 0.0339
# Epoch 2/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0289 - val_loss: 0.0322
# Epoch 3/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0268 - val_loss: 0.0311
# Epoch 4/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0244 - val_loss: 0.0305
# Epoch 5/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0229 - val_loss: 0.0291
# Epoch 6/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0208 - val_loss: 0.0285
# Epoch 7/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0195 - val_loss: 0.0281
# Epoch 8/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0184 - val_loss: 0.0267
# Epoch 9/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0171 - val_loss: 0.0270
# Epoch 10/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0161 - val_loss: 0.0260
# Epoch 11/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0150 - val_loss: 0.0255
# Epoch 12/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0142 - val_loss: 0.0253
# Epoch 13/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0135 - val_loss: 0.0252
# Epoch 14/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0128 - val_loss: 0.0249
# Epoch 15/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0122 - val_loss: 0.0247
# Epoch 16/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0119 - val_loss: 0.0250
# Epoch 17/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0113 - val_loss: 0.0251
# Epoch 18/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0111 - val_loss: 0.0249
# Epoch 19/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0109 - val_loss: 0.0250
# Epoch 20/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0108 - val_loss: 0.0247
# Epoch 21/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0105 - val_loss: 0.0243
# Epoch 22/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0105 - val_loss: 0.0246
# Epoch 23/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0105 - val_loss: 0.0246
# Epoch 24/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0105 - val_loss: 0.0248
# Epoch 25/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0104 - val_loss: 0.0239
# Epoch 26/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0103 - val_loss: 0.0253
# Epoch 27/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0102 - val_loss: 0.0242
# Epoch 28/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0102 - val_loss: 0.0244
# Epoch 29/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0100 - val_loss: 0.0254
# Epoch 30/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0100 - val_loss: 0.0251
# Epoch 31/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0103 - val_loss: 0.0247
# Epoch 32/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0102 - val_loss: 0.0253
# Epoch 33/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0101 - val_loss: 0.0248
# Epoch 34/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0248
# Epoch 35/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0099 - val_loss: 0.0251
# Epoch 36/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0100 - val_loss: 0.0242
# Epoch 37/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0099 - val_loss: 0.0250
# Epoch 38/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0099 - val_loss: 0.0243
# Epoch 39/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0242
# Epoch 40/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0100 - val_loss: 0.0243
# Epoch 41/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0100 - val_loss: 0.0249
# Epoch 42/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0099 - val_loss: 0.0245
# Epoch 43/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0247
# Epoch 44/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0243
# Epoch 45/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0099 - val_loss: 0.0243
# Epoch 46/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0099 - val_loss: 0.0239
# Epoch 47/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0238
# Epoch 48/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0240
# Epoch 49/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0097 - val_loss: 0.0240
# Epoch 50/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0098 - val_loss: 0.0239
# Epoch 51/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0098 - val_loss: 0.0241
# Epoch 52/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0246
# Epoch 53/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0238
# Epoch 54/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0244
# Epoch 55/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0097 - val_loss: 0.0243
# Epoch 56/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0243
# Epoch 57/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0231
# Epoch 58/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0239
# Epoch 59/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0097 - val_loss: 0.0241
# Epoch 60/100
# 454/454 [==============================] - 9s 20ms/step - loss: 0.0097 - val_loss: 0.0238
# Epoch 61/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0235
# Epoch 62/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0236
# Epoch 63/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0233
# Epoch 64/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0097 - val_loss: 0.0236
# Epoch 65/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0235
# Epoch 66/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0239
# Epoch 67/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0097 - val_loss: 0.0232
# Epoch 68/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0097 - val_loss: 0.0235
# Epoch 69/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0095 - val_loss: 0.0237
# Epoch 70/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0097 - val_loss: 0.0230
# Epoch 71/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0233
# Epoch 72/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0095 - val_loss: 0.0233
# Epoch 73/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0095 - val_loss: 0.0237
# Epoch 74/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0095 - val_loss: 0.0232
# Epoch 75/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0095 - val_loss: 0.0237
# Epoch 76/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0231
# Epoch 77/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0233
# Epoch 78/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0235
# Epoch 79/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0236
# Epoch 80/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0237
# Epoch 81/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0098 - val_loss: 0.0236
# Epoch 82/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0238
# Epoch 83/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0094 - val_loss: 0.0239
# Epoch 84/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0238
# Epoch 85/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0234
# Epoch 86/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0095 - val_loss: 0.0236
# Epoch 87/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0095 - val_loss: 0.0232
# Epoch 88/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0237
# Epoch 89/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0096 - val_loss: 0.0231
# Epoch 90/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0095 - val_loss: 0.0235
# Epoch 91/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0096 - val_loss: 0.0238
# Epoch 92/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0230
# Epoch 93/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0097 - val_loss: 0.0230
# Epoch 94/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0095 - val_loss: 0.0233
# Epoch 95/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0095 - val_loss: 0.0230
# Epoch 96/100
# 454/454 [==============================] - 10s 21ms/step - loss: 0.0094 - val_loss: 0.0233
# Epoch 97/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0093 - val_loss: 0.0237
# Epoch 98/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0097 - val_loss: 0.0234
# Epoch 99/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0094 - val_loss: 0.0232
# Epoch 100/100
# 454/454 [==============================] - 9s 21ms/step - loss: 0.0096 - val_loss: 0.0235
# Stacked LSTM:
# Mean Absolute Error: 1.11
# Root Mean Square Error: 1.82

# %% [markdown]
# ### **with Preprocessing**

# %% [markdown]
# ### **32-32-32-32**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(2323)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 32, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 32, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 32, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 32))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #validation_split = 0.2
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)
#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 32)            4480
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 32)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 32)            8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 32)            8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 29,473
# Trainable params: 29,473
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 19s 26ms/step - loss: 0.0336 - val_loss: 0.0349
# Epoch 2/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0257 - val_loss: 0.0333
# Epoch 3/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0221 - val_loss: 0.0315
# Epoch 4/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0186 - val_loss: 0.0287
# Epoch 5/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0152 - val_loss: 0.0299
# Epoch 6/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0124 - val_loss: 0.0312
# Epoch 7/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0106 - val_loss: 0.0297
# Epoch 8/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0098 - val_loss: 0.0295
# Epoch 9/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0096 - val_loss: 0.0295
# Epoch 10/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0092 - val_loss: 0.0298
# Epoch 11/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0091 - val_loss: 0.0304
# Epoch 12/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0090 - val_loss: 0.0314
# Epoch 13/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0089 - val_loss: 0.0311
# Epoch 14/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0089 - val_loss: 0.0311
# Epoch 15/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0312
# Epoch 16/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0088 - val_loss: 0.0305
# Epoch 17/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0087 - val_loss: 0.0310
# Epoch 18/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0086 - val_loss: 0.0321
# Epoch 19/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0086 - val_loss: 0.0310
# Epoch 20/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0310
# Epoch 21/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0308
# Epoch 22/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0086 - val_loss: 0.0308
# Epoch 23/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0085 - val_loss: 0.0301
# Epoch 24/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0084 - val_loss: 0.0308
# Epoch 25/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0084 - val_loss: 0.0304
# Epoch 26/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0084 - val_loss: 0.0298
# Epoch 27/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0083 - val_loss: 0.0300
# Epoch 28/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0084 - val_loss: 0.0304
# Epoch 29/100
# 460/460 [==============================] - 11s 24ms/step - loss: 0.0084 - val_loss: 0.0304
# Epoch 30/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0084 - val_loss: 0.0298
# Epoch 31/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0084 - val_loss: 0.0298
# Epoch 32/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0083 - val_loss: 0.0296
# Epoch 33/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0083 - val_loss: 0.0297
# Epoch 34/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0082 - val_loss: 0.0295
# Epoch 35/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0082 - val_loss: 0.0293
# Epoch 36/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0082 - val_loss: 0.0293
# Epoch 37/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0082 - val_loss: 0.0287
# Epoch 38/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0082 - val_loss: 0.0289
# Epoch 39/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0081 - val_loss: 0.0292
# Epoch 40/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0082 - val_loss: 0.0285
# Epoch 41/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0081 - val_loss: 0.0284
# Epoch 42/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0081 - val_loss: 0.0280
# Epoch 43/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0080 - val_loss: 0.0289
# Epoch 44/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0081 - val_loss: 0.0285
# Epoch 45/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0082 - val_loss: 0.0284
# Epoch 46/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0081 - val_loss: 0.0285
# Epoch 47/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0081 - val_loss: 0.0283
# Epoch 48/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0081 - val_loss: 0.0281
# Epoch 49/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0283
# Epoch 50/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0283
# Epoch 51/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0081 - val_loss: 0.0277
# Epoch 52/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0276
# Epoch 53/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0081 - val_loss: 0.0282
# Epoch 54/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0280
# Epoch 55/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0284
# Epoch 56/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0275
# Epoch 57/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0277
# Epoch 58/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0276
# Epoch 59/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0272
# Epoch 60/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0277
# Epoch 61/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0270
# Epoch 62/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0272
# Epoch 63/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0269
# Epoch 64/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0269
# Epoch 65/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0272
# Epoch 66/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0273
# Epoch 67/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0080 - val_loss: 0.0274
# Epoch 68/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0081 - val_loss: 0.0266
# Epoch 69/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0270
# Epoch 70/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0271
# Epoch 71/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0274
# Epoch 72/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0270
# Epoch 73/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0268
# Epoch 74/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0268
# Epoch 75/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0270
# Epoch 76/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0079 - val_loss: 0.0270
# Epoch 77/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0079 - val_loss: 0.0268
# Epoch 78/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0078 - val_loss: 0.0266
# Epoch 79/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0079 - val_loss: 0.0265
# Epoch 80/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0079 - val_loss: 0.0267
# Epoch 81/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0078 - val_loss: 0.0269
# Epoch 82/100
# 460/460 [==============================] - 11s 23ms/step - loss: 0.0078 - val_loss: 0.0264
# Epoch 83/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0264
# Epoch 84/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0079 - val_loss: 0.0265
# Epoch 85/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0264
# Epoch 86/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0263
# Epoch 87/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0261
# Epoch 88/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0266
# Epoch 89/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0077 - val_loss: 0.0265
# Epoch 90/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0256
# Epoch 91/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0077 - val_loss: 0.0263
# Epoch 92/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0078 - val_loss: 0.0260
# Epoch 93/100
# 460/460 [==============================] - 10s 23ms/step - loss: 0.0078 - val_loss: 0.0261
# Epoch 94/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0260
# Epoch 95/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0264
# Epoch 96/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0265
# Epoch 97/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0077 - val_loss: 0.0264
# Epoch 98/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0259
# Epoch 99/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0078 - val_loss: 0.0261
# Epoch 100/100
# 460/460 [==============================] - 10s 22ms/step - loss: 0.0077 - val_loss: 0.0263
# Stacked LSTM:
# Mean Absolute Error: 1.22
# Root Mean Square Error: 1.85

# %% [markdown]
# # **16-16-16-16**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(23)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)

# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)

# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 16, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 16, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 16, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 16))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  #history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)

#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)


def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  #plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM 3 LAYERS')
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 16)            1216
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 16)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 16)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 16)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 7,569
# Trainable params: 7,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 16s 22ms/step - loss: 0.0384 - val_loss: 0.0330
# Epoch 2/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0267 - val_loss: 0.0314
# Epoch 3/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0237 - val_loss: 0.0301
# Epoch 4/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0205 - val_loss: 0.0289
# Epoch 5/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0175 - val_loss: 0.0276
# Epoch 6/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0148 - val_loss: 0.0264
# Epoch 7/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0126 - val_loss: 0.0264
# Epoch 8/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0116 - val_loss: 0.0272
# Epoch 9/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0111 - val_loss: 0.0274
# Epoch 10/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0104 - val_loss: 0.0268
# Epoch 11/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0100 - val_loss: 0.0266
# Epoch 12/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0098 - val_loss: 0.0272
# Epoch 13/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0099 - val_loss: 0.0272
# Epoch 14/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0096 - val_loss: 0.0275
# Epoch 15/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0095 - val_loss: 0.0281
# Epoch 16/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0095 - val_loss: 0.0282
# Epoch 17/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0094 - val_loss: 0.0276
# Epoch 18/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0095 - val_loss: 0.0280
# Epoch 19/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0094 - val_loss: 0.0281
# Epoch 20/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0092 - val_loss: 0.0288
# Epoch 21/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0093 - val_loss: 0.0283
# Epoch 22/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0093 - val_loss: 0.0269
# Epoch 23/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0092 - val_loss: 0.0275
# Epoch 24/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0090 - val_loss: 0.0281
# Epoch 25/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0090 - val_loss: 0.0278
# Epoch 26/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0091 - val_loss: 0.0277
# Epoch 27/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0090 - val_loss: 0.0287
# Epoch 28/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0090 - val_loss: 0.0279
# Epoch 29/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0089 - val_loss: 0.0272
# Epoch 30/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0090 - val_loss: 0.0276
# Epoch 31/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0089 - val_loss: 0.0274
# Epoch 32/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0089 - val_loss: 0.0278
# Epoch 33/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0089 - val_loss: 0.0274
# Epoch 34/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0088 - val_loss: 0.0271
# Epoch 35/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0088 - val_loss: 0.0267
# Epoch 36/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0270
# Epoch 37/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0089 - val_loss: 0.0267
# Epoch 38/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0089 - val_loss: 0.0270
# Epoch 39/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0088 - val_loss: 0.0271
# Epoch 40/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0088 - val_loss: 0.0263
# Epoch 41/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0088 - val_loss: 0.0271
# Epoch 42/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0269
# Epoch 43/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0272
# Epoch 44/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0267
# Epoch 45/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0268
# Epoch 46/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0087 - val_loss: 0.0262
# Epoch 47/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0265
# Epoch 48/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0268
# Epoch 49/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0267
# Epoch 50/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0263
# Epoch 51/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0087 - val_loss: 0.0266
# Epoch 52/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0262
# Epoch 53/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0261
# Epoch 54/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0087 - val_loss: 0.0259
# Epoch 55/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0264
# Epoch 56/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0263
# Epoch 57/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0259
# Epoch 58/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0087 - val_loss: 0.0265
# Epoch 59/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0085 - val_loss: 0.0262
# Epoch 60/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0266
# Epoch 61/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0085 - val_loss: 0.0256
# Epoch 62/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0260
# Epoch 63/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0254
# Epoch 64/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0258
# Epoch 65/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0085 - val_loss: 0.0258
# Epoch 66/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0086 - val_loss: 0.0255
# Epoch 67/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0262
# Epoch 68/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0260
# Epoch 69/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0260
# Epoch 70/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0087 - val_loss: 0.0259
# Epoch 71/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0087 - val_loss: 0.0256
# Epoch 72/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0085 - val_loss: 0.0258
# Epoch 73/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0258
# Epoch 74/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0254
# Epoch 75/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0253
# Epoch 76/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0252
# Epoch 77/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0253
# Epoch 78/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0256
# Epoch 79/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0083 - val_loss: 0.0255
# Epoch 80/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0257
# Epoch 81/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0255
# Epoch 82/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0254
# Epoch 83/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0086 - val_loss: 0.0249
# Epoch 84/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0253
# Epoch 85/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0253
# Epoch 86/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0259
# Epoch 87/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0251
# Epoch 88/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0252
# Epoch 89/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0253
# Epoch 90/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0254
# Epoch 91/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0252
# Epoch 92/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0085 - val_loss: 0.0252
# Epoch 93/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0253
# Epoch 94/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0252
# Epoch 95/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0254
# Epoch 96/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0252
# Epoch 97/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0083 - val_loss: 0.0252
# Epoch 98/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0085 - val_loss: 0.0250
# Epoch 99/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0084 - val_loss: 0.0250
# Epoch 100/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0084 - val_loss: 0.0256
# Stacked LSTM 3 LAYERS:
# Mean Absolute Error: 1.14
# Root Mean Square Error: 1.83

# %% [markdown]
# ### **8-8-8-8**

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(253)
df = pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df.dropna(inplace=True)
df.isnull().sum(axis = 0)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
# Splitting the dataset into the Training set and Test set
train_size = int(len(X) * 0.70)
test_size = len(X) - train_size
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test=y[:train_size], y[train_size:]
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 45, random_state = 0)
regressor.fit(X_train, y_train)

df= pd.read_csv('WP.csv', index_col=0,header=0)
df.drop(['DewPointC', 'tempC','cloudcover','humidity','pressure'], axis=1,inplace=True)
df['Direction'].fillna(df['Direction'].mean(),inplace=True)
df.isnull().sum(axis = 0)
for i in range(len(df)):
  if (pd.isna(df.iloc[i,-1])):
    test_data=df.iloc[i,0:2].values
    test_data=test_data.reshape(-1,2)
    df.iloc[i,-1]=regressor.predict(test_data)

# %%
df.isnull().sum(axis = 0)
#df.drop(['DewPointC', 'tempC'], axis=1,inplace=True)
#df.isnull().sum(axis = 0)

# Split train data and test data
train_size = int(len(df)*0.7)
train_dataset, test_dataset = df.iloc[:train_size],df.iloc[train_size:]
# Plot train and test data
#plt.figure(figsize = (10, 6))
#plt.plot(train_dataset.Energy)
#plt.plot(test_dataset.Energy)
#plt.xlabel('Time (day)')
#plt.ylabel('Daily water consumption ($m^3$/capita.day)')
#plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

# Split train data to X and y
X_train = train_dataset.drop('Energy', axis = 1)
y_train = train_dataset.loc[:,['Energy']]
# Split test data to X and y
X_test = test_dataset.drop('Energy', axis = 1)
y_test = test_dataset.loc[:,['Energy']]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# Create a 3D input
def create_dataset (X, y, time_steps = 1):
  Xs, ys = [], []
  for i in range(len(X)-time_steps+1):
    v = X[i:i+time_steps, :]
    Xs.append(v)
    ys.append(y[i+time_steps-1])
  return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm,TIME_STEPS)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)
# Create stacked LSTM
def create_model(m):
  model = Sequential()
  model.add(m (units = 8, return_sequences = True,input_shape = [X_train.shape[1], X_train.shape[2]]))
  model.add(Dropout(0.2))
  model.add(m (units = 8, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 8, return_sequences = True))
  model.add(Dropout(0.2))
  model.add(m (units = 8))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='linear'))
  #Compile model
  opt = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8)
  model.compile(loss='mse', optimizer=opt)
  return model

# Stacked LSTM
model_SLSTM = create_model(LSTM)
model_SLSTM.summary()

# Fit Stacked LSTM
def fit_model(model):
  early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 25)
  history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  #history = model.fit(X_train, y_train, epochs = 100,validation_split = 0.2, batch_size = 64,shuffle = False)
  return history

history_SLSTM = fit_model(model_SLSTM)

# Plot train loss and validation loss
def plot_loss (history):
  plt.figure(figsize = (10, 6))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.ylabel('Loss')
  plt.xlabel('epoch')
  plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_SLSTM)

#Inverse  tr ans f orm  the  target  v ari able
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# Make prediction
def prediction(model):
  prediction = model.predict(X_test)
  prediction = scaler_y.inverse_transform(prediction)
  return prediction
prediction_SLSTM = prediction(model_SLSTM)

# Define a function to calculate MAE and RMSE
from sklearn.metrics import mean_absolute_error
def evaluate_prediction(predictions, actual, model_name):
  errors = predictions - actual
  mse = np.square(errors).mean()
  rmse = np.sqrt(mse)
  mae = np.abs(errors).mean()
  print(model_name + ':')
  print('Mean Absolute Error: {:.2f}'.format(mae))
  print('Root Mean Square Error: {:.2f}'.format(rmse))
  print('')

evaluate_prediction(prediction_SLSTM, y_test, 'Stacked LSTM')

def plot_future(prediction, y_test):
  plt.figure(figsize=(10, 6))
  #range_future = len(prediction)
  range_future =200
  yt=np.array(y_test)
  pd=np.array(prediction_SLSTM)
  plt.plot(np.arange(range_future), yt[0:200],label='True Future')
  plt.plot(np.arange(range_future),pd[0:200],label='Prediction Value')
  plt.legend(loc='upper left')
  plt.xlabel('Time')
  plt.ylabel('Wind Power Generated')
  plt.savefig('LSTM.png', dpi=200, bbox_inches='tight')

plot_future(prediction_SLSTM, y_test)
# Out:
# Dimension of train data:  (36797, 3)
# Dimension of test data:  (15771, 3)
# (36797, 2)
# (36797, 1)
# (15771, 2)
# (15771, 1)
# X_train.shape:  (36788, 10, 2)
# y_train.shape:  (36788, 1)
# X_test.shape:  (15762, 10, 2)
# y_test.shape:  (15762, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 8)             352
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 8)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 8)             544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 8)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 8)             544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 8)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 8)                 544
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,993
# Trainable params: 1,993
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 460/460 [==============================] - 16s 21ms/step - loss: 0.0420 - val_loss: 0.0351
# Epoch 2/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0285 - val_loss: 0.0330
# Epoch 3/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0266 - val_loss: 0.0331
# Epoch 4/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0248 - val_loss: 0.0313
# Epoch 5/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0223 - val_loss: 0.0303
# Epoch 6/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0202 - val_loss: 0.0288
# Epoch 7/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0188 - val_loss: 0.0280
# Epoch 8/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0173 - val_loss: 0.0269
# Epoch 9/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0158 - val_loss: 0.0266
# Epoch 10/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0148 - val_loss: 0.0259
# Epoch 11/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0141 - val_loss: 0.0258
# Epoch 12/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0134 - val_loss: 0.0258
# Epoch 13/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0127 - val_loss: 0.0254
# Epoch 14/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0122 - val_loss: 0.0258
# Epoch 15/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0121 - val_loss: 0.0250
# Epoch 16/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0118 - val_loss: 0.0259
# Epoch 17/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0113 - val_loss: 0.0258
# Epoch 18/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0114 - val_loss: 0.0254
# Epoch 19/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0110 - val_loss: 0.0257
# Epoch 20/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0110 - val_loss: 0.0246
# Epoch 21/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0107 - val_loss: 0.0259
# Epoch 22/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0109 - val_loss: 0.0252
# Epoch 23/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0107 - val_loss: 0.0257
# Epoch 24/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0106 - val_loss: 0.0259
# Epoch 25/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0105 - val_loss: 0.0255
# Epoch 26/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0105 - val_loss: 0.0258
# Epoch 27/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0103 - val_loss: 0.0249
# Epoch 28/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0103 - val_loss: 0.0259
# Epoch 29/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0103 - val_loss: 0.0257
# Epoch 30/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0102 - val_loss: 0.0258
# Epoch 31/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0104 - val_loss: 0.0256
# Epoch 32/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0103 - val_loss: 0.0263
# Epoch 33/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0103 - val_loss: 0.0257
# Epoch 34/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0101 - val_loss: 0.0258
# Epoch 35/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0101 - val_loss: 0.0257
# Epoch 36/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0101 - val_loss: 0.0255
# Epoch 37/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0101 - val_loss: 0.0255
# Epoch 38/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0100 - val_loss: 0.0256
# Epoch 39/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0101 - val_loss: 0.0261
# Epoch 40/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0099 - val_loss: 0.0259
# Epoch 41/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0100 - val_loss: 0.0259
# Epoch 42/100
# 460/460 [==============================] - 8s 18ms/step - loss: 0.0099 - val_loss: 0.0258
# Epoch 43/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0101 - val_loss: 0.0258
# Epoch 44/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0100 - val_loss: 0.0260
# Epoch 45/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0098 - val_loss: 0.0258
# Epoch 46/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0099 - val_loss: 0.0254
# Epoch 47/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0099 - val_loss: 0.0255
# Epoch 48/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0100 - val_loss: 0.0257
# Epoch 49/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0099 - val_loss: 0.0263
# Epoch 50/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0099 - val_loss: 0.0256
# Epoch 51/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0100 - val_loss: 0.0254
# Epoch 52/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0100 - val_loss: 0.0255
# Epoch 53/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0098 - val_loss: 0.0253
# Epoch 54/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0099 - val_loss: 0.0256
# Epoch 55/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0100 - val_loss: 0.0252
# Epoch 56/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0098 - val_loss: 0.0258
# Epoch 57/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0098 - val_loss: 0.0258
# Epoch 58/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0099 - val_loss: 0.0255
# Epoch 59/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0098 - val_loss: 0.0257
# Epoch 60/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0099 - val_loss: 0.0254
# Epoch 61/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0097 - val_loss: 0.0255
# Epoch 62/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0098 - val_loss: 0.0252
# Epoch 63/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0099 - val_loss: 0.0258
# Epoch 64/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0097 - val_loss: 0.0258
# Epoch 65/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0099 - val_loss: 0.0255
# Epoch 66/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0098 - val_loss: 0.0256
# Epoch 67/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0260
# Epoch 68/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0097 - val_loss: 0.0252
# Epoch 69/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0097 - val_loss: 0.0252
# Epoch 70/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0099 - val_loss: 0.0251
# Epoch 71/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0097 - val_loss: 0.0258
# Epoch 72/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0098 - val_loss: 0.0251
# Epoch 73/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0097 - val_loss: 0.0254
# Epoch 74/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0097 - val_loss: 0.0253
# Epoch 75/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0098 - val_loss: 0.0253
# Epoch 76/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0253
# Epoch 77/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0248
# Epoch 78/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0098 - val_loss: 0.0253
# Epoch 79/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0098 - val_loss: 0.0252
# Epoch 80/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0245
# Epoch 81/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0096 - val_loss: 0.0252
# Epoch 82/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0252
# Epoch 83/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0097 - val_loss: 0.0251
# Epoch 84/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0251
# Epoch 85/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0097 - val_loss: 0.0256
# Epoch 86/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0094 - val_loss: 0.0250
# Epoch 87/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0098 - val_loss: 0.0247
# Epoch 88/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0097 - val_loss: 0.0250
# Epoch 89/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0244
# Epoch 90/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0097 - val_loss: 0.0248
# Epoch 91/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0253
# Epoch 92/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0095 - val_loss: 0.0243
# Epoch 93/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0247
# Epoch 94/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0095 - val_loss: 0.0252
# Epoch 95/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0097 - val_loss: 0.0248
# Epoch 96/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0250
# Epoch 97/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0254
# Epoch 98/100
# 460/460 [==============================] - 9s 19ms/step - loss: 0.0095 - val_loss: 0.0248
# Epoch 99/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0249
# Epoch 100/100
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0096 - val_loss: 0.0244
# Stacked LSTM:
# Mean Absolute Error: 1.08
# Root Mean Square Error: 1.80

# %% [markdown]
# ## **END**
